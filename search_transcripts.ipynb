# %%
# %config Completer.use_jedi = False

# %%
# !ls
# Out:
# Crazcalm's_Tech_Stack
# Crazcalm's_Tech_Stack_TRANSCRIPTS.pkl
# ENGLISH_POS_TEMPLATE.py
# README.md
# Untitled.ipynb
# font
# search_transcripts.ipynb
# selenium_youtube_channel_scraping_subtitles_delta.py
# youtube_urls.pkl

# %%
import pandas as pd

# %%
df01 = pd.read_pickle("Crazcalm's_Tech_Stack_TRANSCRIPTS.pkl")

# %%
df01[df01['TEXT'].str.contains('python')]
# Out:
#       ID  MINUTE                                         LINK  \
# 598   20      22  https://www.youtube.com/watch?v=UZb04tiwFBo
# 955   35       5  https://www.youtube.com/watch?v=h_unLiKM0vc
# 1016  37      24  https://www.youtube.com/watch?v=ZCVvFOPRj2k
# 1040  37      48  https://www.youtube.com/watch?v=ZCVvFOPRj2k
# 1042  37      50  https://www.youtube.com/watch?v=ZCVvFOPRj2k
# 1788  65       0  https://www.youtube.com/watch?v=puKy_wRcA5w
# 1791  65       3  https://www.youtube.com/watch?v=puKy_wRcA5w
# 1793  65       5  https://www.youtube.com/watch?v=puKy_wRcA5w
# 1795  65       7  https://www.youtube.com/watch?v=puKy_wRcA5w
# 1796  65       8  https://www.youtube.com/watch?v=puKy_wRcA5w
# 1797  65       9  https://www.youtube.com/watch?v=puKy_wRcA5w
# 1798  65      10  https://www.youtube.com/watch?v=puKy_wRcA5w
# 2142  78      25  https://www.youtube.com/watch?v=THU2iNXnJj8
#
#                                             TITLE  \
# ...

# %%
df01['TEXT'][455]
